# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from ggplot import *

# %%
crime_data = pd.read_csv("CrimeRate.csv")

# %%
crime_data.head()
# Out:
#      Year  Population1  Violent\ncrime Violent \ncrime \nrate   \
# 0  1994.0  260327021.0       1857670.0                     714
# 1  1995.0  262803276.0       1798792.0                     685
# 2  1996.0  265228572.0       1688540.0                     637
# 3  1997.0  267783607.0       1636096.0                     611
# 4  1998.0  270248003.0       1533887.0                     568
#
#    Murder and\nnonnegligent \nmanslaughter  \
# 0                                  23326.0
# 1                                  21606.0
# 2                                  19645.0
# 3                                  18208.0
# 4                                  16974.0
#
#   Murder and \nnonnegligent \nmanslaughter \nrate   \
# 0                                                9
# 1                                                8
# 2                                                7
# 3                                                7
# 4                                                6
#
# ...

# %%
crime_data.describe()
# Out:
#              Year   Population1  Violent\ncrime  \
# count    20.00000  2.000000e+01    2.000000e+01
# mean   2003.50000  2.898877e+08    1.439004e+06
# std       5.91608  1.831799e+07    1.859538e+05
# min    1994.00000  2.603270e+08    1.163146e+06
# 25%    1998.75000  2.720801e+08    1.351540e+06
# 50%    2003.50000  2.922229e+08    1.423324e+06
# 75%    2008.25000  3.047964e+08    1.463082e+06
# max    2013.00000  3.161288e+08    1.857670e+06
#
#        Murder and\nnonnegligent \nmanslaughter  \
# count                                20.000000
# mean                              16864.250000
# std                                2318.388071
# min                               14196.000000
# 25%                               15491.250000
# 50%                               16347.000000
# 75%                               17173.250000
# max                               23326.000000
#
#        Rape\n(legacy\ndefinition)2\nrate        Robbery  Robbery \nrate   \
# ...

# %%
ggplot(crime_data, aes(x='Robbery', y='Violent\ncrime', size='Population1', color='Year')) + geom_point()
# Out:
# <ggplot: (-9223371915091020179)>

# %%
plt.subplots(figsize=(15,15))
sns.heatmap(crime_data.corr())

# %%
from sklearn.model_selection import train_test_split

# %%
y = crime_data["Violent\ncrime"]
x = crime_data.drop("Violent\ncrime", axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=104)

# %%
x_train.head()
# Out:
#       Year  Population1 Violent \ncrime \nrate   \
# 16  2010.0  309330219.0                     405
# 18  2012.0  313873685.0                     388
# 21     NaN          NaN                     NaN
# 40     NaN          NaN                     NaN
# 32     NaN          NaN                     NaN
#
#     Murder and\nnonnegligent \nmanslaughter  \
# 16                                  14722.0
# 18                                  14856.0
# 21                                      NaN
# 40                                      NaN
# 32                                      NaN
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 16                                                5
# 18                                                5
# 21
# 40                                              NaN
# 32                                              NaN
#
#    Rape\n(legacy\ndefinition)2  Rape\n(legacy\ndefinition)2\nrate   Robbery  \
# ...

# %%
x_test.head()
# Out:
#       Year  Population1 Violent \ncrime \nrate   \
# 29     NaN          NaN                     NaN
# 19  2013.0  316128839.0                     368
# 10  2004.0  293656842.0                     463
# 22     NaN          NaN                     NaN
# 7   2001.0  285317559.0                     505
#
#     Murder and\nnonnegligent \nmanslaughter  \
# 29                                      NaN
# 19                                  14196.0
# 10                                  16148.0
# 22                                      NaN
# 7                                   16037.0
#
#    Murder and \nnonnegligent \nmanslaughter \nrate   \
# 29                                              NaN
# 19                                                5
# 10                                                6
# 22                                              NaN
# 7                                                 6
#
#    Rape\n(legacy\ndefinition)2  Rape\n(legacy\ndefinition)2\nrate   Robbery  \
# ...

# %%
y_train.head()
# Out:
# 16    1251248.0
# 18    1217057.0
# 21          NaN
# 40          NaN
# 32          NaN
# Name: Violent\ncrime, dtype: float64

# %%
y_test.head()
# Out:
# 29          NaN
# 19    1163146.0
# 10    1360088.0
# 22          NaN
# 7     1439480.0
# Name: Violent\ncrime, dtype: float64
